# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
len(os.listdir('/content/drive/MyDrive/Colab Notebooks/deep_learning_project/dataset1/known_images'))
# Out:
# 717

# %%
import pathlib
data_dir = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/deep_learning_project/dataset1/known_images')

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print(image_count)
# Out:
# 715

# %%
image_count2 = len(list(data_dir.glob('normal/*')))
print(image_count2)
# Out:
# 364

# %%
# data3_dir = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/deep_learning_project/dataset1/known_images/normal_0.png')

# data3_dir.head()

# %%
normal = list(data_dir.glob('normal/*'))
PIL.Image.open(str(normal[363]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=395x488 at 0x7F90B2556D10>

# %%
PIL.Image.open(str(normal[1]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=395x488 at 0x7F90B2E48850>

# %%
sick = list(data_dir.glob('sick/*'))
PIL.Image.open(str(sick[0]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=391x488 at 0x7F90C62BC2D0>

# %%
PIL.Image.open(str(sick[1]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=395x488 at 0x7F90B2BE2450>

# %%
batch_size = 256
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 715 files belonging to 2 classes.
# Using 572 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 715 files belonging to 2 classes.
# Using 143 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['normal', 'sick']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (256, 224, 224, 3)
# (256,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(250).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.9809387

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_13 (Rescaling)    (None, 224, 224, 3)       0
#
#  conv2d_24 (Conv2D)          (None, 224, 224, 16)      448
#
#  max_pooling2d_24 (MaxPoolin  (None, 112, 112, 16)     0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 112, 112, 32)      4640
#
#  max_pooling2d_25 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 56, 56, 64)        18496
#
#  max_pooling2d_26 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 50176)             0
#
#  dense_16 (Dense)            (None, 128)               6422656
#
#  dense_17 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 6,446,498
# Trainable params: 6,446,498
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 2s 436ms/step - loss: 1.0519 - accuracy: 0.4510 - val_loss: 0.5989 - val_accuracy: 0.4895
# Epoch 2/30
# 3/3 [==============================] - 1s 169ms/step - loss: 0.5211 - accuracy: 0.6783 - val_loss: 0.4413 - val_accuracy: 0.7902
# Epoch 3/30
# 3/3 [==============================] - 1s 170ms/step - loss: 0.4281 - accuracy: 0.8007 - val_loss: 0.4041 - val_accuracy: 0.8881
# Epoch 4/30
# 3/3 [==============================] - 1s 245ms/step - loss: 0.3119 - accuracy: 0.9056 - val_loss: 0.2705 - val_accuracy: 0.8671
# Epoch 5/30
# 3/3 [==============================] - 1s 168ms/step - loss: 0.2614 - accuracy: 0.8759 - val_loss: 0.2659 - val_accuracy: 0.9231
# Epoch 6/30
# 3/3 [==============================] - 1s 167ms/step - loss: 0.2381 - accuracy: 0.8899 - val_loss: 0.1870 - val_accuracy: 0.9091
# Epoch 7/30
# 3/3 [==============================] - 1s 168ms/step - loss: 0.1614 - accuracy: 0.9388 - val_loss: 0.1759 - val_accuracy: 0.9510
# Epoch 8/30
# 3/3 [==============================] - 1s 247ms/step - loss: 0.1515 - accuracy: 0.9528 - val_loss: 0.1461 - val_accuracy: 0.9441
# Epoch 9/30
# 3/3 [==============================] - 1s 170ms/step - loss: 0.1385 - accuracy: 0.9510 - val_loss: 0.1292 - val_accuracy: 0.9441
# Epoch 10/30
# 3/3 [==============================] - 1s 243ms/step - loss: 0.1097 - accuracy: 0.9650 - val_loss: 0.1290 - val_accuracy: 0.9650
# Epoch 11/30
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0942 - accuracy: 0.9668 - val_loss: 0.1055 - val_accuracy: 0.9510
# Epoch 12/30
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0792 - accuracy: 0.9703 - val_loss: 0.0954 - val_accuracy: 0.9650
# Epoch 13/30
# 3/3 [==============================] - 1s 169ms/step - loss: 0.0603 - accuracy: 0.9773 - val_loss: 0.0861 - val_accuracy: 0.9650
# Epoch 14/30
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0421 - accuracy: 0.9825 - val_loss: 0.0831 - val_accuracy: 0.9650
# Epoch 15/30
# 3/3 [==============================] - 1s 250ms/step - loss: 0.0308 - accuracy: 0.9930 - val_loss: 0.0813 - val_accuracy: 0.9580
# Epoch 16/30
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0251 - accuracy: 0.9948 - val_loss: 0.0842 - val_accuracy: 0.9580
# Epoch 17/30
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0175 - accuracy: 0.9983 - val_loss: 0.0870 - val_accuracy: 0.9580
# Epoch 18/30
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0122 - accuracy: 0.9983 - val_loss: 0.0917 - val_accuracy: 0.9650
# Epoch 19/30
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0094 - accuracy: 0.9983 - val_loss: 0.0932 - val_accuracy: 0.9650
# Epoch 20/30
# 3/3 [==============================] - 1s 169ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.0985 - val_accuracy: 0.9720
# Epoch 21/30
# 3/3 [==============================] - 1s 167ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.1055 - val_accuracy: 0.9580
# Epoch 22/30
# 3/3 [==============================] - 1s 251ms/step - loss: 0.0038 - accuracy: 0.9983 - val_loss: 0.1068 - val_accuracy: 0.9650
# Epoch 23/30
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0033 - accuracy: 0.9983 - val_loss: 0.1196 - val_accuracy: 0.9580
# Epoch 24/30
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9650
# Epoch 25/30
# 3/3 [==============================] - 1s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9650
# Epoch 26/30
# 3/3 [==============================] - 1s 248ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9510
# Epoch 27/30
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9580
# Epoch 28/30
# 3/3 [==============================] - 1s 174ms/step - loss: 7.6326e-04 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.9650
# Epoch 29/30
# 3/3 [==============================] - 1s 169ms/step - loss: 6.1084e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9580
# Epoch 30/30
# 3/3 [==============================] - 1s 171ms/step - loss: 4.5725e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9580

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_13 (Sequential)  (None, 224, 224, 3)       0
#
#  rescaling_14 (Rescaling)    (None, 224, 224, 3)       0
#
#  conv2d_27 (Conv2D)          (None, 224, 224, 16)      448
#
#  max_pooling2d_27 (MaxPoolin  (None, 112, 112, 16)     0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 112, 112, 32)      4640
#
#  max_pooling2d_28 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 56, 56, 64)        18496
#
#  max_pooling2d_29 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 28, 28, 64)        0
#
#  flatten_9 (Flatten)         (None, 50176)             0
#
#  dense_18 (Dense)            (None, 128)               6422656
#
#  dense_19 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 6,446,498
# Trainable params: 6,446,498
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 2s 246ms/step - loss: 1.0617 - accuracy: 0.5017 - val_loss: 0.7819 - val_accuracy: 0.4825
# Epoch 2/30
# 3/3 [==============================] - 1s 270ms/step - loss: 0.6354 - accuracy: 0.6608 - val_loss: 0.5448 - val_accuracy: 0.7273
# Epoch 3/30
# 3/3 [==============================] - 1s 264ms/step - loss: 0.5682 - accuracy: 0.6661 - val_loss: 0.5008 - val_accuracy: 0.7343
# Epoch 4/30
# 3/3 [==============================] - 1s 181ms/step - loss: 0.5010 - accuracy: 0.7570 - val_loss: 0.3895 - val_accuracy: 0.8671
# Epoch 5/30
# 3/3 [==============================] - 1s 182ms/step - loss: 0.4423 - accuracy: 0.7920 - val_loss: 0.3050 - val_accuracy: 0.8741
# Epoch 6/30
# 3/3 [==============================] - 1s 181ms/step - loss: 0.3594 - accuracy: 0.8339 - val_loss: 0.2735 - val_accuracy: 0.8741
# Epoch 7/30
# 3/3 [==============================] - 1s 264ms/step - loss: 0.3377 - accuracy: 0.8304 - val_loss: 0.2758 - val_accuracy: 0.8741
# Epoch 8/30
# 3/3 [==============================] - 1s 263ms/step - loss: 0.3113 - accuracy: 0.8636 - val_loss: 0.2621 - val_accuracy: 0.8741
# Epoch 9/30
# 3/3 [==============================] - 1s 182ms/step - loss: 0.3068 - accuracy: 0.8479 - val_loss: 0.2543 - val_accuracy: 0.8881
# Epoch 10/30
# 3/3 [==============================] - 1s 179ms/step - loss: 0.3033 - accuracy: 0.8636 - val_loss: 0.2568 - val_accuracy: 0.8811
# Epoch 11/30
# 3/3 [==============================] - 1s 184ms/step - loss: 0.3190 - accuracy: 0.8584 - val_loss: 0.2461 - val_accuracy: 0.8811
# Epoch 12/30
# 3/3 [==============================] - 1s 180ms/step - loss: 0.2953 - accuracy: 0.8584 - val_loss: 0.2264 - val_accuracy: 0.9021
# Epoch 13/30
# 3/3 [==============================] - 1s 180ms/step - loss: 0.2992 - accuracy: 0.8741 - val_loss: 0.2685 - val_accuracy: 0.8531
# Epoch 14/30
# 3/3 [==============================] - 1s 265ms/step - loss: 0.2534 - accuracy: 0.8759 - val_loss: 0.2103 - val_accuracy: 0.9091
# Epoch 15/30
# 3/3 [==============================] - 1s 263ms/step - loss: 0.2258 - accuracy: 0.9003 - val_loss: 0.2212 - val_accuracy: 0.8951
# Epoch 16/30
# 3/3 [==============================] - 1s 180ms/step - loss: 0.2422 - accuracy: 0.8916 - val_loss: 0.2016 - val_accuracy: 0.9231
# Epoch 17/30
# 3/3 [==============================] - 1s 180ms/step - loss: 0.2255 - accuracy: 0.8986 - val_loss: 0.1937 - val_accuracy: 0.9161
# Epoch 18/30
# 3/3 [==============================] - 1s 264ms/step - loss: 0.1998 - accuracy: 0.9073 - val_loss: 0.2075 - val_accuracy: 0.9091
# Epoch 19/30
# 3/3 [==============================] - 1s 268ms/step - loss: 0.2149 - accuracy: 0.8969 - val_loss: 0.1572 - val_accuracy: 0.9441
# Epoch 20/30
# 3/3 [==============================] - 1s 265ms/step - loss: 0.2159 - accuracy: 0.9056 - val_loss: 0.2197 - val_accuracy: 0.9021
# Epoch 21/30
# 3/3 [==============================] - 1s 181ms/step - loss: 0.1893 - accuracy: 0.9196 - val_loss: 0.1569 - val_accuracy: 0.9301
# Epoch 22/30
# 3/3 [==============================] - 1s 182ms/step - loss: 0.1848 - accuracy: 0.9266 - val_loss: 0.1533 - val_accuracy: 0.9371
# Epoch 23/30
# 3/3 [==============================] - 1s 183ms/step - loss: 0.1768 - accuracy: 0.9178 - val_loss: 0.1735 - val_accuracy: 0.9301
# Epoch 24/30
# 3/3 [==============================] - 1s 184ms/step - loss: 0.1629 - accuracy: 0.9371 - val_loss: 0.1324 - val_accuracy: 0.9441
# Epoch 25/30
# 3/3 [==============================] - 1s 265ms/step - loss: 0.1674 - accuracy: 0.9406 - val_loss: 0.1293 - val_accuracy: 0.9441
# Epoch 26/30
# 3/3 [==============================] - 1s 191ms/step - loss: 0.1768 - accuracy: 0.9178 - val_loss: 0.2018 - val_accuracy: 0.9161
# Epoch 27/30
# 3/3 [==============================] - 1s 193ms/step - loss: 0.1579 - accuracy: 0.9423 - val_loss: 0.1361 - val_accuracy: 0.9371
# Epoch 28/30
# 3/3 [==============================] - 1s 190ms/step - loss: 0.1677 - accuracy: 0.9266 - val_loss: 0.2561 - val_accuracy: 0.8811
# Epoch 29/30
# 3/3 [==============================] - 1s 193ms/step - loss: 0.2251 - accuracy: 0.9021 - val_loss: 0.1204 - val_accuracy: 0.9580
# Epoch 30/30
# 3/3 [==============================] - 1s 181ms/step - loss: 0.1852 - accuracy: 0.9231 - val_loss: 0.1386 - val_accuracy: 0.9231

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#data_dir = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/deep_learning_project/dataset1/unknown_images')

data2_dir = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/deep_learning_project/dataset2/images/sick_eff29.png')

#data2_dir = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/deep_learning_project/dataset2/images/sick_eff0.png')

# data2_dir = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/deep_learning_project/dataset1/known_images/sick_189.png')


img = tf.keras.utils.load_img(
    data2_dir, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to the class for {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f90b31ec3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# This image most likely belongs to the class for normal with a 82.78 percent confidence.
